# %% [markdown]
# 1- O dataset que você recebeu é estruturado, não estruturado ou semiestruturado? Justifique.
#
# 2- Do que o dataset trata, qual o seu conteúdo/assunto?
#
# 3- Informe caracteristicas do dataset: quantidades de dados, features,data de criacao, idioma, origem,  ....
#
# 4- Ele é um dataset anotado?
#
# 5- Para que tipos de tarefa (agrupamento, classificação, regressão, sumarização, ...) esse dataset poderia ser usado?
#
# 6- O dataset possui qualidade para o uso em Machine Learning?  Caso a resposta seja não, indique os problemas encontrados.

# %%
import pandas as pd

file = '/Users/pedrotomielo/repositories/PUC/Cadeiras/InteligenciaArtificial/Atividade de Aula - Machine Learning e Dados/dados/Atividade_ Dados/8/DadosParaAnalise_1.csv.xlsx'


df = pd.read_excel(
    file)


df
# Out:
#          data  precip  maxima  minima  horas_insol  temp_media  \
# 0  1961-01-01    -1.0   33.80    22.2         11.7       27.08
# 1  1961-01-02     0.0   34.70    22.5          9.5       28.06
# 2  1961-01-03     0.2   27.70    23.1          2.3       24.32
# 3  1961-01-04     2.4   29.40    20.6          8.7       23.56
# 4  1961-01-05     0.0   32.50    18.8         10.1       25.22
# 5  1961-01-06     3.8   26.20    21.9          0.4       23.06
# 6  1961-01-07     1.6   27.80    15.2         11.7       21.34
# 7  1961-01-08     0.0   33.10    16.4         12.0       23.86
# 8  1961-01-09     0.0   35.70    20.6         12.2       27.20
# 9  1961-01-10    26.9   26.70    20.7          2.7       22.84
# 10 1961-01-11     9.7   28.00    19.9         12.1       23.08
# 11 1961-01-12     0.0   32.60    19.6         12.2       25.40
# 12 1961-01-13     0.0   36.40     NaN         11.9       28.44
# 13 1961-01-14     0.0   36.50    25.4          8.0       30.34
# 14 1961-01-15     0.0   37.50    25.3         10.3       30.80
# 15 1961-01-16     0.0   37.40    24.8          8.1       30.08
# 16 1961-01-17     0.0   31.40    23.4          0.2       26.42
# 17 1961-01-18    14.3   27.40    22.6          5.6       24.36
# 18 1961-01-19     0.0   32.40    22.0         11.8       26.46
# 19 1961-01-20     0.0   37.40    21.8         11.2       29.60
# 20 1961-01-21    13.9   31.10    24.2          5.4       26.14
# 21 1961-01-22     0.0   26.80    22.1          4.8       23.50
# 22 1961-01-23     0.0   30.50    19.4         11.5       23.90
# 23 1961-01-24     0.0   32.00    18.2         10.6       24.12
# 24 1961-01-25     0.1   24.60    21.2          0.2       22.24
# 25 1961-01-26     0.0   26.20    18.0          7.8       21.20
# 26 1961-01-27     0.0   27.60    18.4         11.0       22.56
# 27 1961-01-28     0.0   28.90    18.0         10.5       23.20
# 28 1961-01-29     0.0   31.80    20.6          5.9       24.80
# 29 1961-01-30     0.0   33.60    20.5         11.0       25.94
# 30 1961-01-31     0.0   36.40    20.5          9.9       27.66
# 31 1961-02-01     0.0   35.80    22.0          9.5       26.76
# 32 1961-02-02    27.6   32.60    21.5          9.5       25.68
# 33 1961-02-03     0.0   29.50    22.4          9.3       25.22
# 34 1961-02-04     0.0   29.90    19.8          9.4       24.26
# 35 1961-02-05     0.0   31.60    21.4          7.4       25.36
# 36 1961-02-06     0.0   33.60    22.8          6.3       26.28
# 37 1961-02-07     1.3   28.40    22.6          2.0       25.64
# 38 1961-02-08     1.2   28.40    23.0          7.8       24.56
# 39 1961-02-09     0.0   30.60    18.9         10.0       23.98
# 40 1961-02-10     0.0   34.90    20.1          9.5       27.06
# 41 1961-02-11    34.1   29.70    22.1          7.1       25.04
# 42 1961-02-12     0.0   32.30    18.4         10.7       25.38
# 43 1961-02-13     0.0   26.90    21.8          6.6       23.42
# 44 1961-02-14     0.0   27.70    18.2         11.2       22.74
# 45 1961-02-15     0.0   30.90    20.2         11.5       24.38
# 46 1961-02-16     0.0  200.17    20.7         10.5       24.86
# 47 1961-02-17     0.0   32.60    20.1          9.3       25.58
# 48 1961-02-18     0.0   32.60    22.2          8.7       26.28
# 49 1961-02-19     3.6   32.90    21.7         11.2       26.16
#
#     umidade_relativa     vel_vento
# 0              67.00  2.333333e+06
# 1              62.50  1.333333e+06
# 2              74.25  2.000000e+00
# 3              57.50  2.333333e+06
# 4              63.50  3.666667e+06
# 5              80.75  2.666667e+06
# 6              57.25  1.666667e+06
# 7              62.00  1.333333e+06
# 8              61.25  1.666667e+06
# 9              88.25  2.666667e+06
# 10             64.25  2.000000e+00
# 11             70.75  2.000000e+00
# 12             63.00  1.333333e+06
# 13             58.50  1.666667e+06
# 14             60.00  1.666667e+06
# 15             66.50  3.333330e-01
# 16             81.25  2.333333e+06
# 17             73.50  3.000000e+00
# 18             76.75  2.333333e+06
# 19             64.00  1.000000e+00
# 20             77.50  3.000000e+00
# 21             66.25  2.666667e+06
# 22             61.75  2.666667e+06
# 23             72.00  2.666667e+06
# 24             64.75  3.333333e+06
# 25             67.50  3.000000e+00
# 26             59.25  3.000000e+00
# 27             63.50  2.666667e+06
# 28             64.00  1.333333e+06
# 29             59.25  1.666667e+06
# 30             58.00  1.333333e+06
# 31             69.75  1.333333e+06
# 32             73.00  3.000000e+00
# 33             71.75  2.333333e+06
# 34             68.25  3.000000e+00
# 35             70.00  2.000000e+00
# 36             76.00  1.666667e+06
# 37             77.00  2.000000e+00
# 38             74.50  2.666667e+06
# 39             66.00  2.333333e+06
# 40             65.75  2.000000e+00
# 41             78.00  1.666667e+06
# 42             59.00  1.000000e+00
# 43             65.25  2.666667e+06
# 44             60.50  4.666667e+06
# 45             59.25  4.000000e+00
# 46             62.75  3.333333e+06
# 47             67.00  1.666667e+06
# 48             77.75  2.000000e+00
# 49             73.50  1.666667e+06

# %%
df.describe()
# Out:
#                       data     precip      maxima     minima  horas_insol  \
# count                   50  50.000000   50.000000  49.000000    50.000000
# mean   1961-01-25 12:00:00   2.794000   34.703400  20.975510     8.576000
# min    1961-01-01 00:00:00  -1.000000   24.600000  15.200000     0.200000
# 25%    1961-01-13 06:00:00   0.000000   28.400000  19.800000     7.175000
# 50%    1961-01-25 12:00:00   0.000000   31.700000  21.200000     9.500000
# 75%    1961-02-06 18:00:00   0.175000   33.600000  22.200000    11.150000
# max    1961-02-19 00:00:00  34.100000  200.170000  25.400000    12.200000
# std                    NaN   7.545168   24.116541   2.147725     3.351001
#
#        temp_media  umidade_relativa     vel_vento
# count   50.000000         50.000000  5.000000e+01
# mean    25.308400         67.630000  1.466667e+06
# min     21.200000         57.250000  3.333330e-01
# 25%     23.870000         62.125000  3.000000e+00
# 50%     25.220000         66.125000  1.666667e+06
# 75%     26.385000         73.375000  2.333333e+06
# max     30.800000         88.250000  4.666667e+06
# std      2.198853          7.328349  1.238094e+06

# %% [markdown]
# **O dataset é estruturado.**
#
# Está organizado em formato tabular no modelo n × d (objetos × atributos). Cada linha representa um dia, cada coluna um atributo meteorológico
#
# ---
#
# **1. Do que o dataset trata?**
#
# Trata-se de dados meteorológicos diários. Cada registro corresponde a um dia e contém medições de precipitação, temperatura (máxima, mínima e média), horas de insolação, umidade relativa do ar e velocidade do vento. O recorte temporal aparente começa em 01/01/1961.
#
# ---
#
# **2. Características do dataset**
#
# | Característica | Valor / Observação |
# |---|---|
# | Tipo | Série temporal diária |
# | Início observado | 01/01/1961 |
# | Número de features | 8 colunas (data, precip, maxima, minima, horas_insol, temp_media, umidade_relativa, vel_vento) |
# | Idioma | Português (nomes das colunas) |
# | Granularidade | 1 registro por dia |
# | Tipos de atributos | Quantitativos contínuos (todos, exceto `data`) |
# | Escala dos atributos | Intervalar/Racional |
#
# ---
#
# **3. É um dataset anotado?**
#
# **Não**, no sentido clássico de Machine Learning supervisionado. Não há uma coluna de rótulo (label/classe) explicitamente definida
#
# ---
#
# **4. Para quais tarefas poderia ser usado?**
#
# | Tarefa | Aplicação possível |
# |---|---|
# | **Regressão** | Prever temperatura média, precipitação ou umidade do dia seguinte |
# | **Classificação** | Classificar dias como chuvoso/seco, quente/frio (após criar rótulos) |
# | **Agrupamento (Clustering)** | Identificar padrões sazonais ou tipos de dias climáticos sem supervisão |
# | **Detecção de anomalias** | Identificar eventos climáticos extremos (ondas de calor, secas) |
#
#
# ---
#
# **5. O dataset possui qualidade para uso em Machine Learning?**
#
# **Parcialmente.** Há pelo menos dois problemas evidentes já nas 5 primeiras linhas:
#
# **Problema 1 — Valor inválido em `precip` (linha 0):**
# O valor `-1.0` para precipitação é fisicamente impossível — precipitação não pode ser negativa. Provavelmente representa um valor ausente codificado numericamente (convenção comum no INMET: `-1` ou `-9999` para dados faltantes). Isso precisa ser tratado antes de qualquer modelagem.
#
# **Problema 2 — Valores absurdos em `vel_vento`:**
# Os valores `2333333.0`, `1333333.0` e `3666667.0` são claramente erros de dados — velocidade do vento medida em m/s ou km/h jamais atingiria esses valores. Indica provável erro de parsing (vírgula interpretada como separador decimal incorreto, ou encoding quebrado). A linha 2 tem `2.0`, que seria o único valor plausível.
#
# **Resumo dos problemas:**
#
# | Problema | Coluna afetada | Ação recomendada |
# |---|---|---|
# | Valor negativo impossível | `precip` | Tratar como NaN e imputar ou remover |
# | Valores absurdos | `vel_vento` | Investigar encoding/parsing, corrigir ou remover |
# | Possíveis outros missing values | Todas | Verificar toda a série com `df.isnull()` e `df.describe()` |
