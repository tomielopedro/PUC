# %%
import pandas as pd
df = pd.read_csv('cardio_v2.csv', sep=';')
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0  110.0     80            1     1
# 1          1  20228       1     156    85.0  140.0     -1            3     1
# 2          2  18857       1     165    64.0  130.0     70            3     1
# 3          3  17623       2     169    82.0  150.0    100            1     1
# 4          4  17474       1     156    56.0  100.0     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0  120.0     80            1     1
# 69996  99995  22601       1     158   126.0  140.0     90            2     2
# 69997  99996  19066       2     183   105.0  180.0     90            3     1
# 69998  99998  22431       1     163    72.0  135.0     80            1     2
# 69999  99999  20540       1     170    72.0  120.0     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        69999 non-null  float64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(2), int64(11)
# memory usage: 6.9 MB

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.362086     74.205690
# std    28851.302323   2467.251667      0.476838      8.246808     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    370.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  69999.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.816983     96.629114      1.366871      1.226457      0.088129
# ...

# %% [markdown]
# ### 1- Há dados faltantes ou incorretos? Se tiver, como você fará a correção?
#
# Não identifiquei ainda

# %% [markdown]
# ### 2- Transforme a idade para anos

# %%
df['age'] = df['age']//365
df.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0   50       2     168    62.0  110.0     80            1     1      0
# 1   1   55       1     156    85.0  140.0     -1            3     1      0
# 2   2   51       1     165    64.0  130.0     70            3     1      0
# 3   3   48       2     169    82.0  150.0    100            1     1      0
# 4   4   47       1     156    56.0  100.0     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# ### 3- Introdução uma coluna com o cálculo do IMC

# %%
df['imc'] = df['weight']/((df['height']/100)**2)
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       2     168    62.0  110.0     80            1     1
# 1          1   55       1     156    85.0  140.0     -1            3     1
# 2          2   51       1     165    64.0  130.0     70            3     1
# 3          3   48       2     169    82.0  150.0    100            1     1
# 4          4   47       1     156    56.0  100.0     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   52       2     168    76.0  120.0     80            1     1
# 69996  99995   61       1     158   126.0  140.0     90            2     2
# 69997  99996   52       2     183   105.0  180.0     90            3     1
# 69998  99998   61       1     163    72.0  135.0     80            1     2
# 69999  99999   56       1     170    72.0  120.0     80            2     1
#
#        smoke  alco  active  cardio        imc
# ...

# %% [markdown]
# ### 4- Calcule

# %% [markdown]
# #### 4.1- Total de dados

# %%
print('Total linhas: ', len(df))
# Out:
# Total linhas:  70000

# %% [markdown]
# #### 4.2- Quantidade de dados por gênero

# %%
import matplotlib as plt
## 1 FEMININO 
## 2 MASCULINO
print(df['gender'].value_counts())
df['gender'].hist()
# Out:
# gender
# 1    45530
# 2    24470
# Name: count, dtype: int64
# <Axes: >

# %% [markdown]
# #### 4.2 - Menor altura, maior altura e média de altura
# #### 4.3- Menor peso, maior peso e média de peso
# #### 4.4- Menor idade, maior idade e média de idade

# %%
df[['height', 'weight', 'age']].describe()
# Out:
#              height        weight           age
# count  70000.000000  70000.000000  70000.000000
# mean     164.362086     74.205690     52.840671
# std        8.246808     14.395757      6.766774
# min       55.000000     10.000000     29.000000
# 25%      159.000000     65.000000     48.000000
# 50%      165.000000     72.000000     53.000000
# 75%      170.000000     82.000000     58.000000
# max      370.000000    200.000000     64.000000

# %% [markdown]
# #### 4.6- Valor médio da pressão para a baixa (ap_lo) e para alta (ap_hi).

# %%
print(f'Média pressão baixa (ap_lo): {df['ap_lo'].mean():.2f}')
print(f'Média pressão alta (ap_hi): {df['ap_hi'].mean():.2f}')
# Out:
# Média pressão baixa (ap_lo): 96.63
# Média pressão alta (ap_hi): 128.82

# %% [markdown]
# #### 4.7- Quantas pessoas tem doença cardiovascular?

# %%
display(df['cardio'].value_counts())
df['cardio'].hist()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64
# <Axes: >

# %% [markdown]
# #### 5- O dataset pode ser usado para classificação? Se sim, ele está balanceado? Detalhe/Visualize por gráfico
#
# R: sim, pode ser usado para classificacao e está balanceado

# %%
df['cardio'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cardio'>

# %% [markdown]
# #### 6- Existe alguma relação entre a taxa de colesterol e a presença da doença? Detalhe/Visualize por gráfico

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df[['cardio','cholesterol', 'smoke', 'active', 'gluc', 'imc']].corr()

sns.heatmap(corr, annot=True)
plt.show()
print(corr)
# Out:
#                cardio  cholesterol     smoke    active      gluc       imc
# cardio       1.000000     0.221147 -0.015486 -0.035653  0.089307  0.165658
# cholesterol  0.221147     1.000000  0.010354  0.009911  0.451578  0.146279
# smoke       -0.015486     0.010354  1.000000  0.025858 -0.004756 -0.027199
# active      -0.035653     0.009911  0.025858  1.000000 -0.006770 -0.014280
# gluc         0.089307     0.451578 -0.004756 -0.006770  1.000000  0.101397
# imc          0.165658     0.146279 -0.027199 -0.014280  0.101397  1.000000
